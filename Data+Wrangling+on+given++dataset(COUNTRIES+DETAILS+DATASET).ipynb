# %%
import pandas as pd

# %%
import numpy as np

# %%
df1=pd.read_csv(r'C:\Users\Srikala\Desktop\data1.csv')

# %%
df1
# Out:
#                                            Indicator" PUBLISH STATES  Year  \
# 0                    Life expectancy at birth (years)      Published  1990
# 1                    Life expectancy at birth (years)      Published  2000
# 2                   Life expectancy at age 60 (years)      Published  2012
# 3                   Life expectancy at age 60 (years)      Published  2000
# 4                    Life expectancy at birth (years)      Published  2012
# 5                    Life expectancy at birth (years)      Published  2000
# 6                   Life expectancy at age 60 (years)      Published  1990
# 7                   Life expectancy at age 60 (years)      Published  2012
# 8                    Life expectancy at birth (years)      Published  2012
# 9                    Life expectancy at birth (years)      Published  2000
# 10                   Life expectancy at birth (years)      Published  2012
# ...

# %% [markdown]
# 1)To get meta data from above example

# %%
df1.info() #Meta Data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
# Indicator"                 4656 non-null object
# PUBLISH STATES             4656 non-null object
# Year                       4656 non-null int64
# WHO region                 4656 non-null object
# World Bank income group    4656 non-null object
# Country                    4656 non-null object
# Sex                        4656 non-null object
# Display Value              4656 non-null int64
# Numeric                    4656 non-null float64
# Low                        0 non-null float64
# High                       0 non-null float64
# Comments                   0 non-null float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB

# %% [markdown]
# 2.) Get the row names from the above files.

# %%
s=df1.index
np.where(s)
# Out:
# (array([   1,    2,    3, ..., 4653, 4654, 4655], dtype=int64),)

# %% [markdown]
# 3). Change the column name from any of the above file.

# %%
df1.head()
# Out:
#                           Indicator" PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# ...

# %%
df1.rename(columns={'Indicator"':'indicator_id'}) #relaced indicator with idicator_id
# Out:
#       indicator_id PUBLISH STATES  Year             WHO region  \
# 0     indicator_id      Published  1990                 Europe
# 1     indicator_id      Published  2000                 Europe
# 2     indicator_id      Published  2012                 Europe
# 3     indicator_id      Published  2000                 Europe
# 4     indicator_id      Published  2012  Eastern Mediterranean
# 5     indicator_id      Published  2000               Americas
# 6     indicator_id      Published  1990               Americas
# 7     indicator_id      Published  2012               Americas
# 8     indicator_id      Published  2012        Western Pacific
# 9     indicator_id      Published  2000        Western Pacific
# 10    indicator_id      Published  2012        Western Pacific
# 11    indicator_id      Published  2012                 Europe
# 12    indicator_id      Published  2012                 Europe
# 13    indicator_id      Published  2012                 Europe
# ...

# %% [markdown]
# 4). Change the column name from any of the above file and store the changes made
# permanently.

# %%
df1.rename(columns={'Indicator"':'indicator_id'},inplace=True)

# %%
df1
# Out:
#                                          indicator_id PUBLISH STATES  Year  \
# 0                    Life expectancy at birth (years)      Published  1990
# 1                    Life expectancy at birth (years)      Published  2000
# 2                   Life expectancy at age 60 (years)      Published  2012
# 3                   Life expectancy at age 60 (years)      Published  2000
# 4                    Life expectancy at birth (years)      Published  2012
# 5                    Life expectancy at birth (years)      Published  2000
# 6                   Life expectancy at age 60 (years)      Published  1990
# 7                   Life expectancy at age 60 (years)      Published  2012
# 8                    Life expectancy at birth (years)      Published  2012
# 9                    Life expectancy at birth (years)      Published  2000
# 10                   Life expectancy at birth (years)      Published  2012
# ...

# %% [markdown]
# 5.) Change the names of multiple columns.

# %%
df1.rename(columns={'PUBLISH STATES' : 'publication states', 'WHO region' : "WHO Region"},inplace=True)

# %%
df1
# Out:
#                                          indicator_id publication states  \
# 0                    Life expectancy at birth (years)          Published
# 1                    Life expectancy at birth (years)          Published
# 2                   Life expectancy at age 60 (years)          Published
# 3                   Life expectancy at age 60 (years)          Published
# 4                    Life expectancy at birth (years)          Published
# 5                    Life expectancy at birth (years)          Published
# 6                   Life expectancy at age 60 (years)          Published
# 7                   Life expectancy at age 60 (years)          Published
# 8                    Life expectancy at birth (years)          Published
# 9                    Life expectancy at birth (years)          Published
# 10                   Life expectancy at birth (years)          Published
# 11                   Life expectancy at birth (years)          Published
# ...

# %% [markdown]
# Arrange values of a particular column in ascending order.

# %%
df2=df1.sort_values(by ='Display Value',axis=0)

# %%
df2
# Out:
#                              Indicator" PUBLISH STATES  Year  \
# 265   Life expectancy at age 60 (years)      Published  2000
# 1476  Life expectancy at age 60 (years)      Published  1990
# 1474  Life expectancy at age 60 (years)      Published  1990
# 3070  Life expectancy at age 60 (years)      Published  2000
# 3072  Life expectancy at age 60 (years)      Published  2000
# 1813  Life expectancy at age 60 (years)      Published  1990
# 3071  Life expectancy at age 60 (years)      Published  1990
# 3203  Life expectancy at age 60 (years)      Published  1990
# 2032  Life expectancy at age 60 (years)      Published  2000
# 577   Life expectancy at age 60 (years)      Published  1990
# 2987  Life expectancy at age 60 (years)      Published  2000
# 1475  Life expectancy at age 60 (years)      Published  2012
# 4275  Life expectancy at age 60 (years)      Published  1990
# 256   Life expectancy at age 60 (years)      Published  2000
# ...

# %% [markdown]
# 7). Arrange multiple column values in ascending order.

# %%
df3=df1.sort_values(by =['Display Value','Year'],axis=0)

# %%
df3
# Out:
#                              Indicator" PUBLISH STATES  Year  \
# 1474  Life expectancy at age 60 (years)      Published  1990
# 1476  Life expectancy at age 60 (years)      Published  1990
# 1813  Life expectancy at age 60 (years)      Published  1990
# 3071  Life expectancy at age 60 (years)      Published  1990
# 265   Life expectancy at age 60 (years)      Published  2000
# 3070  Life expectancy at age 60 (years)      Published  2000
# 3072  Life expectancy at age 60 (years)      Published  2000
# 577   Life expectancy at age 60 (years)      Published  1990
# 3203  Life expectancy at age 60 (years)      Published  1990
# 4275  Life expectancy at age 60 (years)      Published  1990
# 256   Life expectancy at age 60 (years)      Published  2000
# 2032  Life expectancy at age 60 (years)      Published  2000
# 2987  Life expectancy at age 60 (years)      Published  2000
# 3981  Life expectancy at age 60 (years)      Published  2000
# ...

# %% [markdown]
# 8). Make country​ as the first column of the dataframe.

# %%
df1=df1[['Country','Indicator"', 'PUBLISH STATES', 'Year', 'WHO region',
       'World Bank income group', 'Sex', 'Display Value', 'Numeric',
       'Low', 'High', 'Comments']]

# %%
df1
# Out:
#                                  Country  \
# 0                                Andorra
# 1                                Andorra
# 2                                Andorra
# 3                                Andorra
# 4                   United Arab Emirates
# 5                    Antigua and Barbuda
# 6                    Antigua and Barbuda
# 7                    Antigua and Barbuda
# 8                              Australia
# 9                              Australia
# 10                             Australia
# 11                               Austria
# 12                               Austria
# 13                               Belgium
# 14                               Bahrain
# 15                               Bahrain
# 16                               Bahrain
# 17                               Bahamas
# 18                               Bahamas
# 19                              Barbados
# 20                              Barbados
# 21                              Barbados
# ...

# %% [markdown]
# 9). Get the column array using a variable

# %%
n=df1['WHO region']
df5=np.array([n])
df5
# Out:
# array([['Europe', 'Europe', 'Europe', ..., 'Africa', 'Africa', 'Africa']], dtype=object)

# %% [markdown]
# Get the subset rows 11, 24, 37

# %%
df1.loc[[11,24,37]]
# Out:
#               Country                         Indicator" PUBLISH STATES  Year  \
# 11            Austria   Life expectancy at birth (years)      Published  2012
# 24  Brunei Darussalam  Life expectancy at age 60 (years)      Published  2012
# 37             Cyprus  Life expectancy at age 60 (years)      Published  2012
#
#          WHO region World Bank income group     Sex  Display Value  Numeric  \
# 11           Europe             High-income  Female             83     83.0
# 24  Western Pacific             High-income  Female             21     21.0
# 37           Europe             High-income  Female             26     26.0
#
#     Low  High  Comments
# 11  NaN   NaN       NaN
# 24  NaN   NaN       NaN
# 37  NaN   NaN       NaN

# %% [markdown]
# 11. Get the subset rows excluding 5, 12, 23, and 56

# %%
df3=df1.index.isin([5,12,23,56])
df3
# Out:
# array([False, False, False, ..., False, False, False], dtype=bool)

# %%
s=df1[~df3]

# %%
s
# Out:
#                                  Country  \
# 0                                Andorra
# 1                                Andorra
# 2                                Andorra
# 3                                Andorra
# 4                   United Arab Emirates
# 6                    Antigua and Barbuda
# 7                    Antigua and Barbuda
# 8                              Australia
# 9                              Australia
# 10                             Australia
# 11                               Austria
# 13                               Belgium
# 14                               Bahrain
# 15                               Bahrain
# 16                               Bahrain
# 17                               Bahamas
# 18                               Bahamas
# 19                              Barbados
# 20                              Barbados
# 21                              Barbados
# 22                     Brunei Darussalam
# 24                     Brunei Darussalam
# ...
